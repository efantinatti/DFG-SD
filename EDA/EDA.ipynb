# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1. Load the Dataset
df = pd.read_csv('../Dataset/education-economy-data.csv')

# %%
# Display first few rows and data info to check structure
print("Dataset Info:")
print(df.info())
display(df.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       191 non-null    object
#  1   Literacy Rate                 191 non-null    float64
#  2   Physician Density             191 non-null    float64
#  3   GDP (Current USD)             191 non-null    float64
#  4   GDP Growth (% Annual)         191 non-null    float64
#  5   GDP per Capita (Current USD)  191 non-null    float64
#  6   GDP per Capita Category       191 non-null    object
#  7   Unemployment Rate (%)         191 non-null    float64
#  8   Continent                     191 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 13.6+ KB
# None
#        Country  Literacy Rate  Physician Density  GDP (Current USD)  \
# 0  Afghanistan           43.0               0.28       1.723305e+10
# ...

# %%
# 2. Descriptive Statistics
# -------------------------
desc_stats = df.describe()
print("\nDescriptive Statistics:")
display(desc_stats)

# Set plotting style
sns.set_theme(style="whitegrid")
# Out:
# Descriptive Statistics:
#        Literacy Rate  Physician Density  GDP (Current USD)  \
# count     191.000000         191.000000       1.910000e+02
# mean       86.994764           1.848639       5.427605e+11
# std        17.622097           1.679639       2.452696e+12
# min        26.800000           0.010000       6.228031e+07
# 25%        81.800000           0.345000       1.356848e+10
# 50%        95.600000           1.470000       4.260088e+10
# 75%        99.000000           2.950000       2.651225e+11
# max       100.000000           8.420000       2.772070e+13
#
#        GDP Growth (% Annual)  GDP per Capita (Current USD)  \
# count             191.000000                    191.000000
# mean                2.666018                  18796.795066
# std                 4.362681                  30535.286667
# min               -20.111576                    193.007146
# 25%                 0.979868                   2284.223590
# ...

# %%
 #3. Visualizations

# Figure A: Distributions of Key Indicators
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Literacy Rate Distribution
sns.histplot(df['Literacy Rate'], kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribution of Literacy Rate')

# GDP per Capita Distribution
sns.histplot(df['GDP per Capita (Current USD)'], kde=True, ax=axes[1], color='salmon')
axes[1].set_title('Distribution of GDP per Capita')

# Unemployment Rate Distribution
sns.histplot(df['Unemployment Rate (%)'], kde=True, ax=axes[2], color='green')
axes[2].set_title('Distribution of Unemployment Rate')

plt.tight_layout()
plt.show()

# Figure B: Correlation Heatmap
plt.figure(figsize=(10, 8))
# Select only numeric columns for correlation matrix
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Economic & Social Indicators')
plt.tight_layout()
plt.show()

# Figure C: Literacy Rate vs. GDP per Capita (by Continent)
plt.figure(figsize=(12, 7))
sns.scatterplot(
    data=df, 
    x='Literacy Rate', 
    y='GDP per Capita (Current USD)', 
    hue='Continent', 
    palette='viridis', 
    s=100, 
    alpha=0.8
)
plt.title('Literacy Rate vs. GDP per Capita by Continent')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Figure D: Unemployment Rate by GDP Category
plt.figure(figsize=(10, 6))
# Define order for the categorical variable
category_order = ['Very Low', 'Low', 'Mid', 'High']

sns.boxplot(
    data=df, 
    x='GDP per Capita Category', 
    y='Unemployment Rate (%)', 
    order=category_order, 
    palette="Set2"
)
plt.title('Unemployment Rate by GDP per Capita Category')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/5m/gz4l5p8s54xd89j_gyjxqg4w0000gn/T/ipykernel_383/1623542624.py:53: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load the Dataset
# -------------------
df = pd.read_csv('education-economy-data.csv')

# Display first few rows and data info to check structure
print("Dataset Info:")
print(df.info())
display(df.head())

# 2. Descriptive Statistics
# -------------------------
desc_stats = df.describe()
print("\nDescriptive Statistics:")
display(desc_stats)

# Set plotting style
sns.set_theme(style="whitegrid")

# 3. Visualizations
# -----------------

# Figure A: Distributions of Key Indicators
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Literacy Rate Distribution
sns.histplot(df['Literacy Rate'], kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribution of Literacy Rate')

# GDP per Capita Distribution
sns.histplot(df['GDP per Capita (Current USD)'], kde=True, ax=axes[1], color='salmon')
axes[1].set_title('Distribution of GDP per Capita')

# Unemployment Rate Distribution
sns.histplot(df['Unemployment Rate (%)'], kde=True, ax=axes[2], color='green')
axes[2].set_title('Distribution of Unemployment Rate')

plt.tight_layout()
plt.show()

# Figure B: Correlation Heatmap
plt.figure(figsize=(10, 8))
# Select only numeric columns for correlation matrix
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Economic & Social Indicators')
plt.tight_layout()
plt.show()

# Figure C: Literacy Rate vs. GDP per Capita (by Continent)
plt.figure(figsize=(12, 7))
sns.scatterplot(
    data=df, 
    x='Literacy Rate', 
    y='GDP per Capita (Current USD)', 
    hue='Continent', 
    palette='viridis', 
    s=100, 
    alpha=0.8
)
plt.title('Literacy Rate vs. GDP per Capita by Continent')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Figure D: Unemployment Rate by GDP Category
plt.figure(figsize=(10, 6))
# Define order for the categorical variable
category_order = ['Very Low', 'Low', 'Mid', 'High']

sns.boxplot(
    data=df, 
    x='GDP per Capita Category', 
    y='Unemployment Rate (%)', 
    order=category_order, 
    palette="Set2"
)
plt.title('Unemployment Rate by GDP per Capita Category')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 7
#       3 import seaborn as sns
#       5 # 1. Load the Dataset
#       6 # -------------------
# ----> 7 df = pd.read_csv('education-economy-data.csv')
#       9 # Display first few rows and data info to check structure
#      10 print("Dataset Info:")
#
# ...
